# %% [markdown]
# <a href="https://colab.research.google.com/github/python4recursion/bookcode/blob/main/c/c_debug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pdb
def f(x):
  pdb.set_trace()
  if (x <= 0):
    return x
  else:
    y = f(x -1)
    return (x * y)
a = f(5)
# Out:
# > /tmp/ipython-input-3282820433.py(4)f()
#       2 def f(x):
#       3   pdb.set_trace()
# ----> 4   if (x <= 0):
#       5     return x
#       6   else:
