# %% [markdown]
# <a href="https://colab.research.google.com/github/python4recursion/bookcode/blob/main/2/2_5_parentheses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Section 2.5: parentheses.py
def helper(parentheses, total, left, right, results):
    # parentheses: array to store ( or ) used
    # total: total number of pairs
    # left: how many ( have been used
    # right: how many ) have been used
    ind = left + right
    outstr = '' # empty string
    if (left == total):
        # use up all (
        # remaining are all )
        for i in range(0, ind):
            outstr = outstr + parentheses[i]
        for i in range(right, total):
            outstr = outstr + ')'
        results.append(outstr)
        return
    # next one can always be (
    parentheses[ind] = '('
    helper(parentheses, total, left + 1, right, results)
    # ) can be used only if more ( have been used than )
    if (left > right):
        parentheses[ind] = ')'
        helper(parentheses, total, left, right + 1, results)
def generate(n):
    results = []
    parentheses = ['0'] * (2 * n)
    helper(parentheses, n, 0, 0, results)
    return results

# %%
import random
def testgenerate():
    n = random.randint(3,9)
    results = generate(n)
    for res in results:
      print(res)
    print(f'n = {n}, {len(results)} results')
testgenerate()
# Out:
# ((()))
# (()())
# (())()
# ()(())
# ()()()
# n = 3, 5 results
