# %% [markdown]
# <a href="https://colab.research.google.com/github/python4recursion/bookcode/blob/main/2/2_10_1_factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Section 2.9.1: factorial1.py
import sys
def f1(n):
  if (n == 1):
    return 1
  return n * f1(n - 1)

# %%
def f2(n):
  if (n == 1):
    return 1
  product = 1
  for x in range(2, n + 1):
    product *= x
  return product

# %%
import timeit
for n in range(41, 51):
  if (f1(n) != f2(n)):
    print(f'f1({n}) = {f1(n)}, f2({n}) = {f2(n)}')
  t1 = timeit.timeit(lambda: f1(n), number = 10000)
  t2 = timeit.timeit(lambda: f2(n), number = 10000)
  print(f'n = {n}, t1= {t1:.6e}, t2 = {t2:.6e}, ratio = {t1/t2:.4}')
# Out:
# n = 41, t1= 4.055400e-02, t2 = 3.127151e-02, ratio = 1.297
# n = 42, t1= 4.198190e-02, t2 = 2.701503e-02, ratio = 1.554
# n = 43, t1= 4.254361e-02, t2 = 2.759581e-02, ratio = 1.542
# n = 44, t1= 4.300595e-02, t2 = 3.223995e-02, ratio = 1.334
# n = 45, t1= 4.418152e-02, t2 = 3.082441e-02, ratio = 1.433
# n = 46, t1= 4.497132e-02, t2 = 2.937980e-02, ratio = 1.531
# n = 47, t1= 4.611847e-02, t2 = 3.289959e-02, ratio = 1.402
# n = 48, t1= 4.635357e-02, t2 = 2.741286e-02, ratio = 1.691
# n = 49, t1= 4.604656e-02, t2 = 2.977703e-02, ratio = 1.546
# n = 50, t1= 4.675175e-02, t2 = 3.282295e-02, ratio = 1.424
