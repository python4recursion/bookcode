# %% [markdown]
# <a href="https://colab.research.google.com/github/python4recursion/bookcode/blob/main/Appendix-C/C_1_Latex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Appendix C-1: show latex equation

# %% [markdown]
# Write a function that implements $a = \frac{b}{\sqrt{c}}$

# %%
import math
def calculate_a(b, c):
  if (c < 0)
    raise ValueError("c cannot be negative")
  else:
    a = b / math.sqrt(c)
    return a
