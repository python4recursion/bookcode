# %% [markdown]
# <a href="https://colab.research.google.com/github/python4recursion/bookcode/blob/main/Appendix-D/D_5_testcount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Appendix D.5: testcount.py
# %%capture
# !pip install nbconvert > /dev/null 2>&1

# %%
# %%capture
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
code_path = '/content/drive/My Drive/Colab Notebooks/Recursion Book/CH02 Recursive Programs/'
notebook_path = code_path + '2-4-partition.ipynb'
python_path = code_path + 'partition.py'
# !python -m nbconvert --to python "$notebook_path" --output "$python_path"
import sys
sys.path.append(code_path)
from partition import partition

# %%
import unittest
import random
import copy
class TestFunc(unittest.TestCase):
  def test_sort(self):
    for numtest in range(3, 10):
      n = random.randint(5, 20)
      result = partition(n)
      sum = 0
      for i in range (len (result)):
        sum += result[i].count(1)
      self.assertEqual(sum, (n + 2) * (2 ** (n-3)))
      self.assertEqual(len(result), 2 ** (n-1))
if __name__ == "__main__":
  unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.285s
#
# OK
