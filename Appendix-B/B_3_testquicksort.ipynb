# %% [markdown]
# <a href="https://colab.research.google.com/github/python4recursion/bookcode/blob/main/B/B_3_testquicksort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Appendix B.3: testquicksort.py
# %%capture
# !pip install nbconvert > /dev/null 2>&1
from google.colab import drive
drive.mount('/content/drive', force_remount = True)

# %%
# %%capture
code_path = '/content/drive/My Drive/Colab Notebooks/Recursion Book/CH02 Recursive Programs/'
notebook_path = code_path + '2-8-quicksort.ipynb'
python_path = code_path + 'quicksort.py'
# !python -m nbconvert --to python "$notebook_path" --output "$python_path"
import sys
sys.path.append(code_path)
from quicksort import quickSort
# Out:
# /content/drive/My Drive/Colab Notebooks/Recursion Book/CH02 Recursive Programs/2-8-quicksort.ipynb
# /content/drive/My Drive/Colab Notebooks/Recursion Book/CH02 Recursive Programs/quicksort.py
# [NbConvertApp] Converting notebook /content/drive/My Drive/Colab Notebooks/Recursion Book/CH02 Recursive Programs/2-8-quicksort.ipynb to python
# [NbConvertApp] Writing 1121 bytes to /content/drive/My Drive/Colab Notebooks/Recursion Book/CH02 Recursive Programs/quicksort.py

# %%
import unittest
import random
import copy
class TestFunc(unittest.TestCase):
  def test_sort(self):
    time1 = 0
    time2 = 0
    for numtest in range(10):
      size = random.randint(1000, 100000)
      data1 = [random.randint(-10000, 100000) for _ in range(size)]
      data2 = copy.deepcopy(data1)
      result1 = quickSort(data1)
      result2 = sorted(data2)
      self.assertEqual(result1, result2)
if __name__ == "__main__":
  unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 5.034s
#
# OK
